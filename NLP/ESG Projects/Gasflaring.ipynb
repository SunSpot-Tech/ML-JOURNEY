# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(Niger_Delta_Gas_Flare_Dataset.csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = pd.read_csv(Niger_Delta_Gas_Flare_Dataset.csv)
#
# NameError: name 'Niger_Delta_Gas_Flare_Dataset' is not defined
