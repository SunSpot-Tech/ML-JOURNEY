# %%
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
df = pd.read_csv('Data.csv')  
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.head()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes

# %%
df.tail()
# Out:
#    Country   Age   Salary Purchased
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.shape
# Out:
# (10, 4)

# %%
df.columns
# Out:
# Index(['Country', 'Age', 'Salary', 'Purchased'], dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    10 non-null     str
#  1   Age        9 non-null      float64
#  2   Salary     9 non-null      float64
#  3   Purchased  10 non-null     str
# dtypes: float64(2), str(2)
# memory usage: 452.0 bytes

# %%
df.describe()
# Out:
#              Age        Salary
# count   9.000000      9.000000
# mean   38.777778  63777.777778
# std     7.693793  12265.579662
# min    27.000000  48000.000000
# 25%    35.000000  54000.000000
# 50%    38.000000  61000.000000
# 75%    44.000000  72000.000000
# max    50.000000  83000.000000

# %%
df.isnull() # or df.isna()
# Out:
#    Country    Age  Salary  Purchased
# 0    False  False   False      False
# 1    False  False   False      False
# 2    False  False   False      False
# 3    False  False   False      False
# 4    False  False    True      False
# 5    False  False   False      False
# 6    False   True   False      False
# 7    False  False   False      False
# 8    False  False   False      False
# 9    False  False   False      False

# %%
df.isna().sum() # or df.isnull().sum()
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
sns.scatterplot(x='Age', y='Salary', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
sns.pairplot(df)

# %%
df['Country'].unique()
# Out:
# <StringArray>
# ['France', 'Spain', 'Germany']
# Length: 3, dtype: str

# %%
df['Country'].nunique()
# Out:
# 3

# %%
df['Country'].value_counts()
# Out:
# Country
# France     4
# Spain      3
# Germany    3
# Name: count, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Country
# France     4
# Spain      3
# Germany    3
# Name: count, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 44.0    1
# 27.0    1
# 30.0    1
# 38.0    1
# 40.0    1
# 35.0    1
# 48.0    1
# 50.0    1
# 37.0    1
# Name: count, dtype: int64

# %%
df['Salary'].value_counts()
# Out:
# Salary
# 72000.0    1
# 48000.0    1
# 54000.0    1
# 61000.0    1
# 58000.0    1
# 52000.0    1
# 79000.0    1
# 83000.0    1
# 67000.0    1
# Name: count, dtype: int64

# %%
df['Purchased'].value_counts()
# Out:
# Purchased
# No     5
# Yes    5
# Name: count, dtype: int64

# %%
df['Age'].hist()
# Out:
# <Axes: >

# %%
df['Salary'].hist()
# Out:
# <Axes: >

# %%
sns.histplot(data=df, x='Age', bins=10, binwidth=5)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=df, x='Salary', bins=10, binwidth=5000,)
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
sns.histplot(data=df, x='Salary', bins=10, binwidth=5000, hue='Purchased', multiple='stack')
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
sns.histplot(data=df, x='Age', bins=10, binwidth=5, hue='Purchased', multiple='stack')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df.boxplot(column='Age')
# Out:
# <Axes: >

# %%
df.boxplot(column='Salary')
# Out:
# <Axes: >

# %%
df['Age'].describe()
# Out:
# count     9.000000
# mean     38.777778
# std       7.693793
# min      27.000000
# 25%      35.000000
# 50%      38.000000
# 75%      44.000000
# max      50.000000
# Name: Age, dtype: float64

# %%
df['Country'].describe()
# Out:
# count         10
# unique         3
# top       France
# freq           4
# Name: Country, dtype: object

# %%
df['Salary'].describe()
# Out:
# count        9.000000
# mean     63777.777778
# std      12265.579662
# min      48000.000000
# 25%      54000.000000
# 50%      61000.000000
# 75%      72000.000000
# max      83000.000000
# Name: Salary, dtype: float64

# %%
df['Purchased'].describe()
# Out:
# count     10
# unique     2
# top       No
# freq       5
# Name: Purchased, dtype: object

# %%
df.corr(numeric_only = True)
# Out:
#              Age    Salary
# Age     1.000000  0.982495
# Salary  0.982495  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.groupby('Age')['Salary'].mean()
# Out:
# Age
# 27.0    48000.0
# 30.0    54000.0
# 35.0    58000.0
# 37.0    67000.0
# 38.0    61000.0
# 40.0        NaN
# 44.0    72000.0
# 48.0    79000.0
# 50.0    83000.0
# Name: Salary, dtype: float64

# %%
df.groupby('Age')['Salary'].sum()
# Out:
# Age
# 27.0    48000.0
# 30.0    54000.0
# 35.0    58000.0
# 37.0    67000.0
# 38.0    61000.0
# 40.0        0.0
# 44.0    72000.0
# 48.0    79000.0
# 50.0    83000.0
# Name: Salary, dtype: float64

# %%
df.dropna()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.fillna(5)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      0.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   0.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].mean())
df
# Out:
#    Country   Age        Salary Purchased
# 0   France  44.0  72000.000000        No
# 1    Spain  27.0  48000.000000       Yes
# 2  Germany  30.0  54000.000000        No
# 3    Spain  38.0  61000.000000        No
# 4  Germany  40.0  63777.777778       Yes
# 5   France  35.0  58000.000000       Yes
# 6    Spain   NaN  52000.000000        No
# 7   France  48.0  79000.000000       Yes
# 8  Germany  50.0  83000.000000        No
# 9   France  37.0  67000.000000       Yes

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  63777.777778       Yes
# 5   France  35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  63777.777778       Yes
# 5   France  35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes

# %%
df.drop_duplicates(subset='Country')
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No

# %%
df.drop_duplicates(subset='Age')
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  63777.777778       Yes
# 5   France  35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes

# %%
df.drop_duplicates(subset='Purchased')
# Out:
#   Country   Age   Salary Purchased
# 0  France  44.0  72000.0        No
# 1   Spain  27.0  48000.0       Yes

# %%
df.drop_duplicates(subset='Salary')
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  63777.777778       Yes
# 5   France  35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes

# %%
df['Salary'] = df['Salary'].astype(int)
df
# Out:
#    Country  Age  Salary Purchased
# 0   France   44   72000        No
# 1    Spain   27   48000       Yes
# 2  Germany   30   54000        No
# 3    Spain   38   61000        No
# 4  Germany   40   63777       Yes
# 5   France   35   58000       Yes
# 6    Spain   38   52000        No
# 7   France   48   79000       Yes
# 8  Germany   50   83000        No
# 9   France   37   67000       Yes

# %%
df['Age'] = df['Age'].astype(int)
df
# Out:
#    Country  Age  Salary Purchased
# 0   France   44   72000        No
# 1    Spain   27   48000       Yes
# 2  Germany   30   54000        No
# 3    Spain   38   61000        No
# 4  Germany   40   63777       Yes
# 5   France   35   58000       Yes
# 6    Spain   38   52000        No
# 7   France   48   79000       Yes
# 8  Germany   50   83000        No
# 9   France   37   67000       Yes

# %%
df['Age'] = pd.to_datetime(df['Age'])
df
# Out:
#    Country                           Age  Salary Purchased
# 0   France 1970-01-01 00:00:00.000000044   72000        No
# 1    Spain 1970-01-01 00:00:00.000000027   48000       Yes
# 2  Germany 1970-01-01 00:00:00.000000030   54000        No
# 3    Spain 1970-01-01 00:00:00.000000038   61000        No
# 4  Germany 1970-01-01 00:00:00.000000040   63777       Yes
# 5   France 1970-01-01 00:00:00.000000035   58000       Yes
# 6    Spain 1970-01-01 00:00:00.000000038   52000        No
# 7   France 1970-01-01 00:00:00.000000048   79000       Yes
# 8  Germany 1970-01-01 00:00:00.000000050   83000        No
# 9   France 1970-01-01 00:00:00.000000037   67000       Yes

# %%
df['Salary'] = pd.to_datetime(df['Salary'])
df
# Out:
#    Country                           Age                        Salary  \
# 0   France 1970-01-01 00:00:00.000000044 1970-01-01 00:00:00.000072000
# 1    Spain 1970-01-01 00:00:00.000000027 1970-01-01 00:00:00.000048000
# 2  Germany 1970-01-01 00:00:00.000000030 1970-01-01 00:00:00.000054000
# 3    Spain 1970-01-01 00:00:00.000000038 1970-01-01 00:00:00.000061000
# 4  Germany 1970-01-01 00:00:00.000000040 1970-01-01 00:00:00.000063777
# 5   France 1970-01-01 00:00:00.000000035 1970-01-01 00:00:00.000058000
# 6    Spain 1970-01-01 00:00:00.000000038 1970-01-01 00:00:00.000052000
# 7   France 1970-01-01 00:00:00.000000048 1970-01-01 00:00:00.000079000
# 8  Germany 1970-01-01 00:00:00.000000050 1970-01-01 00:00:00.000083000
# 9   France 1970-01-01 00:00:00.000000037 1970-01-01 00:00:00.000067000
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5       Yes
# 6        No
# 7       Yes
# 8        No
# 9       Yes

# %%
# Apply IQR on numeric columns
for col in ['Age', 'Salary']:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)]

# %%
print(f"--- {col} ---")
# Out:
# --- Salary ---

# %%
print(f"Q1: {Q1}, Q3: {Q3}, IQR: {IQR}")
# Out:
# Q1: 54000.0, Q3: 72000.0, IQR: 18000.0

# %%
print(f"Lower Bound: {lower}, Upper Bound: {upper}")
# Out:
# Lower Bound: 27000.0, Upper Bound: 99000.0

# %%
print(f"Outliers:\n{outliers[['Country', col]]}\n")
# Out:
# Outliers:
# Empty DataFrame
# Columns: [Country, Salary]
# Index: []

# %%
# Remove outliers from both columns
clean_df = df.copy()
for col in ['Age', 'Salary']:
    Q1 = clean_df[col].quantile(0.25)
    Q3 = clean_df[col].quantile(0.75)
    IQR = Q3 - Q1
    clean_df = clean_df[(clean_df[col] >= Q1 - 1.5 * IQR) & (clean_df[col] <= Q3 + 1.5 * IQR)]

# %%
print("Clean Data:")
# Out:
# Clean Data:

# %%
print(clean_df)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes
