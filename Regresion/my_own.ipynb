# %%
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
df = pd.read_csv('ml.csv')
df
# Out:
#      customer_id  age  tenure_months  monthly_charges  total_charges  \
# 0              1   56             11            64.64        4683.75
# 1              2   69             26           106.42        4521.54
# 2              3   46             63            75.81         931.55
# 3              4   32             59            73.99        1422.14
# 4              5   60             27            23.42        7779.00
# ..           ...  ...            ...              ...            ...
# 995          996   18             37            79.60        7234.44
# 996          997   35             47            30.13        7475.21
# 997          998   49             37           104.71        6430.65
# 998          999   64             49            73.11        5426.64
# 999         1000   66             44           104.17         145.18
#
#       contract_type    payment_method internet_service tech_support  \
# 0    Month-to-month      Mailed check      Fiber optic           No
# ...

# %%
df.shape
# Out:
# (1000, 14)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'tenure_months', 'monthly_charges',
#        'total_charges', 'contract_type', 'payment_method', 'internet_service',
#        'tech_support', 'online_security', 'paperless_billing',
#        'num_support_tickets', 'satisfaction_score', 'churn'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_id          1000 non-null   int64
#  1   age                  1000 non-null   int64
#  2   tenure_months        1000 non-null   int64
#  3   monthly_charges      1000 non-null   float64
#  4   total_charges        1000 non-null   float64
#  5   contract_type        1000 non-null   str
#  6   payment_method       1000 non-null   str
#  7   internet_service     1000 non-null   str
#  8   tech_support         1000 non-null   str
#  9   online_security      1000 non-null   str
#  10  paperless_billing    1000 non-null   str
#  11  num_support_tickets  1000 non-null   int64
#  12  satisfaction_score   1000 non-null   int64
#  13  churn                1000 non-null   int64
# dtypes: float64(2), int64(6), str(6)
# memory usage: 109.5 KB

# %%
df.describe()
# Out:
#        customer_id          age  tenure_months  monthly_charges  \
# count  1000.000000  1000.000000     1000.00000      1000.000000
# mean    500.500000    49.857000       35.19000        69.266890
# std     288.819436    18.114267       20.42506        28.793363
# min       1.000000    18.000000        1.00000        20.020000
# 25%     250.750000    35.000000       17.00000        43.450000
# 50%     500.500000    50.000000       35.50000        69.675000
# 75%     750.250000    66.000000       53.00000        94.597500
# max    1000.000000    79.000000       71.00000       119.710000
#
#        total_charges  num_support_tickets  satisfaction_score        churn
# count     1000.00000           1000.00000         1000.000000  1000.000000
# mean      4187.46378              2.01600            2.980000     0.436000
# std       2246.67774              1.42821            1.425353     0.496135
# min        103.50000              0.00000            1.000000     0.000000
# ...

# %%
sns.histplot(data=df, x='age', bins=10, binwidth=5, hue='churn', multiple='stack')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=df, x='monthly_charges', bins=10, binwidth=5, hue='churn', multiple='stack')
# Out:
# <Axes: xlabel='monthly_charges', ylabel='Count'>

# %%
sns.histplot(data=df, x='tenure_months', bins=10, binwidth=5, hue='churn', multiple='stack')
# Out:
# <Axes: xlabel='tenure_months', ylabel='Count'>

# %%
sns.histplot(data=df, x='total_charges', bins=10, binwidth=5, hue='churn', multiple='stack')
# Out:
# <Axes: xlabel='total_charges', ylabel='Count'>

# %%
df['tenure_months'].plot(kind = 'pie')
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >
